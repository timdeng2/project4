# %%
# !nvidia-smi
# Out:
# Mon Apr 27 09:34:57 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0             46W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
import subprocess
subprocess.run(['kill', '-9', '17581'])
# Out:
# CompletedProcess(args=['kill', '-9', '17581'], returncode=0)

# %%
import psutil

ram_gb = psutil.virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))
# Out:
# Your runtime has 89.6 gigabytes of available RAM

# %%
# !git clone https://github.com/timdeng2/project4.git /content/project4

# %%
# !wget https://utexas.box.com/shared/static/qubjm5isldqvyimfj9rsmbnvnbezwcv4.zip -O /content/project4/supertux_data.zip

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/project4/supertux_data.zip -d /content/project4/

# %%
import sys
from pathlib import Path

sys.path.insert(0, '/content/project4')
DATA_DIR = Path('/content/project4/data')

# %%
# !pip install -r /content/project4/requirements.txt

# %%
import os
print(os.listdir('/content/project4'))
print(os.listdir('/content/project4/data'))
# Out:
# ['homework', 'requirements.txt', 'data', 'README.md', 'supertux_data.zip', 'grader', 'bundle.py', '.gitignore', 'simple_scripts.py', '.git']
# ['train', 'valid']

# %%
# %cd /content/project4
# Out:
# /content/project4

# %%
import os
os.getcwd()
# Out:
# '/content/project4'

# %%
os.path.exists('/content/project4/data/train/example_captions.json')
# Out:
# True

# %%
# !cp /content/drive/MyDrive/example_captions.json /content/project4/data/train/

# %%
# !git fetch origin
# !git reset --hard origin/main
# Out:
# HEAD is now at 629babd params

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 334 bytes | 334.00 KiB/s, done.
# From https://github.com/timdeng2/project4
#    6efab5e..d183b67  main       -> origin/main
# Updating 6efab5e..d183b67
# Fast-forward
#  homework/clip.py | 3 ++-
#  1 file changed, 2 insertions(+), 1 deletion(-)

# %%
import torch
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Mon Apr 27 09:43:29 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0             47W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
from homework.finetune import train
train()

# %%
# !cp -r /content/project4/homework/vlm_model /content/drive/MyDrive/vlm_model

# %%
import importlib
import homework.clip
importlib.reload(homework.clip)
from homework.clip import train
from pathlib import Path
train(data_dir=Path("data"))
# Out:
# trainable params: 3,769,344 || all params: 224,877,249 || trainable%: 1.6762
# Loaded 270052 captions for train split
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_60973/2763254286.py in <cell line: 0>()
#       4 from homework.clip import train
#       5 from pathlib import Path
# ----> 6 train(data_dir=Path("data"))
#
# /content/project4/homework/clip.py in train(data_dir, output_dir, num_train_epochs, per_device_train_batch_size, gradient_accumulation_steps, learning_rate, num_workers)
#     322     )
#     323
# --> 324     trainer.train()
#     325
#     326     # save model
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2238                 hf_hub_utils.enable_progress_bars()
#    2239         else:
# -> 2240             return inner_training_loop(
# ...

# %%
# %cd /content/project4
# !git fetch origin
# !git reset --hard origin/main
# Out:
# /content/project4
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 352 bytes | 352.00 KiB/s, done.
# From https://github.com/timdeng2/project4
#    d183b67..5837b2e  main       -> origin/main
# HEAD is now at 5837b2e asdasd?

# %%
print(type(vision_encoder))
print(vision_encoder)
# Out:
# <class 'transformers.models.idefics3.modeling_idefics3.Idefics3VisionTransformer'>
# Idefics3VisionTransformer(
#   (embeddings): Idefics3VisionEmbeddings(
#     (patch_embedding): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16), padding=valid)
#     (position_embedding): Embedding(1024, 768)
#   )
#   (encoder): Idefics3Encoder(
#     (layers): ModuleList(
#       (0-11): 12 x Idefics3EncoderLayer(
#         (self_attn): Idefics3VisionAttention(
#           (k_proj): Linear(in_features=768, out_features=768, bias=True)
#           (v_proj): Linear(in_features=768, out_features=768, bias=True)
#           (q_proj): Linear(in_features=768, out_features=768, bias=True)
#           (out_proj): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (layer_norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): Idefics3VisionMLP(
#           (activation_fn): PytorchGELUTanh()
# ...

# %%
import torch
dummy = torch.zeros(1, 3, 192, 192).to("cuda").bfloat16()
out = vision_encoder(pixel_values=dummy)
print(out)
print(out.last_hidden_state.shape)
# Out:
# BaseModelOutput(last_hidden_state=tensor([[[-0.6719,  1.5000, -0.6914,  ...,  0.4062,  0.1309,  1.2734],
#          [ 2.2656,  1.4062,  0.6875,  ...,  0.3242, -2.1562,  1.0234],
#          [ 0.4727,  0.3555,  0.8672,  ..., -1.0625, -1.2266,  1.5078],
#          ...,
#          [ 0.0371,  0.1226,  0.2871,  ..., -0.5352,  0.5664,  0.6641],
#          [ 1.3828,  1.0625,  1.7109,  ...,  0.9492,  0.0461,  1.7969],
#          [ 0.2168,  0.1504,  0.4043,  ..., -0.1768,  0.3262,  0.2656]]],
#        device='cuda:0', dtype=torch.bfloat16, grad_fn=<NativeLayerNormBackward0>), hidden_states=None, attentions=None)
# torch.Size([1, 144, 768])
